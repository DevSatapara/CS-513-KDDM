# %%
# Course ID:- CS-513A
# Course Instructor:- Khashayar Dehnad
# Name:- Dev Satapara
# CWID:- 20021369
# Assignment Brief:- Performed Exploratry Data Analysis of given dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\satap\\OneDrive\\Desktop\\STEVENS\\CS-513\\breast-cancer-wisconsin.csv", na_values='?')
df
# Out:
#       Sample  F1  F2  F3  F4  F5    F6  F7  F8  F9  Class
# 0    1000025   5   1   1   1   2   1.0   3   1   1      2
# 1    1002945   5   4   4   5   7  10.0   3   2   1      2
# 2    1015425   3   1   1   1   2   2.0   3   1   1      2
# 3    1016277   6   8   8   1   3   4.0   3   7   1      2
# 4    1017023   4   1   1   3   2   1.0   3   1   1      2
# ..       ...  ..  ..  ..  ..  ..   ...  ..  ..  ..    ...
# 694   776715   3   1   1   1   3   2.0   1   1   1      2
# 695   841769   2   1   1   1   2   1.0   1   1   1      2
# 696   888820   5  10  10   3   7   3.0   8  10   2      4
# 697   897471   4   8   6   4   3   4.0  10   6   1      4
# 698   897471   4   8   8   5   4   5.0  10   4   1      4
#
# [699 rows x 11 columns]

# %% [markdown]
# Summarizing Each Column

# %%
df.describe()
# Out:
#              Sample          F1          F2          F3          F4  \
# count  6.990000e+02  699.000000  699.000000  699.000000  699.000000
# mean   1.071704e+06    4.417740    3.134478    3.207439    2.806867
# std    6.170957e+05    2.815741    3.051459    2.971913    2.855379
# min    6.163400e+04    1.000000    1.000000    1.000000    1.000000
# 25%    8.706885e+05    2.000000    1.000000    1.000000    1.000000
# 50%    1.171710e+06    4.000000    1.000000    1.000000    1.000000
# 75%    1.238298e+06    6.000000    5.000000    5.000000    4.000000
# max    1.345435e+07   10.000000   10.000000   10.000000   10.000000
#
#                F5          F6          F7          F8          F9       Class
# count  699.000000  683.000000  699.000000  699.000000  699.000000  699.000000
# mean     3.216023    3.544656    3.437768    2.866953    1.589413    2.689557
# std      2.214300    3.643857    2.438364    3.053634    1.715078    0.951273
# ...

# %% [markdown]
# Indetifying missing values and replacing them with mean of the column

# %%
df.replace('?', np.nan,inplace=True)

# %%
df.fillna(df.mean(),inplace=True)

# %% [markdown]
# Frequency Table between 'Class' and 'F6'

# %%
ft  = pd.crosstab(df['Class'],df['F6'])
ft
# Out:
# F6     1.000000   2.000000   3.000000   3.544656   4.000000   5.000000   \
# Class
# 2            387         21         14         14          6         10
# 4             15          9         14          2         13         20
#
# F6     6.000000   7.000000   8.000000   9.000000   10.000000
# Class
# 2              0          1          2          0          3
# 4              4          7         19          9        129

# %% [markdown]
# Displaying the scatter plot of F1 to F6, one pair at a time

# %%
import seaborn as sns

sns.pairplot(df.iloc[:,1:7],diag_kind='None')
# Out:
# c:\Users\satap\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Show histogram box plot for columns F7 to F9

# %%
df.iloc[:, 7:10].plot(kind='box', subplots=True)
plt.suptitle("Histogram Box Plot for Columns F7 to F9")
plt.show()

# %% [markdown]
# Remove any row with a missing value in any of the columns

# %%
del df,ft

# %%
df = pd.read_csv("C:\\Users\\satap\\OneDrive\\Desktop\\STEVENS\\CS-513\\breast-cancer-wisconsin.csv",na_values='?')
df
# Out:
#       Sample  F1  F2  F3  F4  F5    F6  F7  F8  F9  Class
# 0    1000025   5   1   1   1   2   1.0   3   1   1      2
# 1    1002945   5   4   4   5   7  10.0   3   2   1      2
# 2    1015425   3   1   1   1   2   2.0   3   1   1      2
# 3    1016277   6   8   8   1   3   4.0   3   7   1      2
# 4    1017023   4   1   1   3   2   1.0   3   1   1      2
# ..       ...  ..  ..  ..  ..  ..   ...  ..  ..  ..    ...
# 694   776715   3   1   1   1   3   2.0   1   1   1      2
# 695   841769   2   1   1   1   2   1.0   1   1   1      2
# 696   888820   5  10  10   3   7   3.0   8  10   2      4
# 697   897471   4   8   6   4   3   4.0  10   6   1      4
# 698   897471   4   8   8   5   4   5.0  10   4   1      4
#
# [699 rows x 11 columns]

# %%
df.dropna(axis=0, inplace=True)

# %%
df
# Out:
#       Sample  F1  F2  F3  F4  F5    F6  F7  F8  F9  Class
# 0    1000025   5   1   1   1   2   1.0   3   1   1      2
# 1    1002945   5   4   4   5   7  10.0   3   2   1      2
# 2    1015425   3   1   1   1   2   2.0   3   1   1      2
# 3    1016277   6   8   8   1   3   4.0   3   7   1      2
# 4    1017023   4   1   1   3   2   1.0   3   1   1      2
# ..       ...  ..  ..  ..  ..  ..   ...  ..  ..  ..    ...
# 694   776715   3   1   1   1   3   2.0   1   1   1      2
# 695   841769   2   1   1   1   2   1.0   1   1   1      2
# 696   888820   5  10  10   3   7   3.0   8  10   2      4
# 697   897471   4   8   6   4   3   4.0  10   6   1      4
# 698   897471   4   8   8   5   4   5.0  10   4   1      4
#
# [683 rows x 11 columns]

# %% [markdown]
# It can be seen that number of rows has been reduced from 699 to 683 after deleting the rows with null values in it
