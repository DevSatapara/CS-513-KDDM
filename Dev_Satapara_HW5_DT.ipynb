# %%
# Course ID:- CS-513A
# Course Instructor:- Khashayar Dehnad
# Name:- Dev Satapara
# CWID:- 20021369
# Assignment Brief:- Performed CART Methodology to develop a classification model(Decision Tree) for given dataset.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, d
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
header_names = ["SampleCode", "ClumpThickness", "UniformityCellSize", "UniformityCellShape", "MarginalAdhesion", "SingleEpithelialCellSize", "BareNuclei", "BlandChromatin", "NormalNucleoli", "Mitoses", "Class"]

# %%
df =  pd.read_csv('C:\\Users\\satap\\OneDrive\\Desktop\\STEVENS\\CS-513\\breast-cancer-wisconsin.csv',header=None,skiprows=1, names=header_names,na_values='?')
df
# Out:
#      SampleCode  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0       1000025               5                   1                    1
# 1       1002945               5                   4                    4
# 2       1015425               3                   1                    1
# 3       1016277               6                   8                    8
# 4       1017023               4                   1                    1
# ..          ...             ...                 ...                  ...
# 694      776715               3                   1                    1
# 695      841769               2                   1                    1
# 696      888820               5                  10                   10
# 697      897471               4                   8                    6
# 698      897471               4                   8                    8
#
#      MarginalAdhesion  SingleEpithelialCellSize  BareNuclei  BlandChromatin  \
# ...

# %%
df['Class'] = df['Class'].map({2: 'Benign', 4: 'Malignant'}).fillna(df['Class'])
df
# Out:
#      SampleCode  ClumpThickness  UniformityCellSize  UniformityCellShape  \
# 0       1000025               5                   1                    1
# 1       1002945               5                   4                    4
# 2       1015425               3                   1                    1
# 3       1016277               6                   8                    8
# 4       1017023               4                   1                    1
# ..          ...             ...                 ...                  ...
# 694      776715               3                   1                    1
# 695      841769               2                   1                    1
# 696      888820               5                  10                   10
# 697      897471               4                   8                    6
# 698      897471               4                   8                    8
#
#      MarginalAdhesion  SingleEpithelialCellSize  BareNuclei  BlandChromatin  \
# ...

# %%
X = df.drop(columns=['Class','SampleCode'], axis=1)
y = df['Class']
X = pd.DataFrame(MinMaxScaler().fit_transform(X), columns=X.columns)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
cart = DecisionTreeClassifier()
cart.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predicted = cart.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, predicted)
print(conf_matrix)
# Out:
# [[138   5]
#  [  6  61]]

# %%
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.96      0.97      0.96       143
#    Malignant       0.92      0.91      0.92        67
#
#     accuracy                           0.95       210
#    macro avg       0.94      0.94      0.94       210
# weighted avg       0.95      0.95      0.95       210

# %%
plt.figure(figsize=(50,30), dpi=250)
plot_tree(cart,fontsize=20,filled=True,feature_names=X.columns)
# Out:
# [Text(0.3625919117647059, 0.9545454545454546, 'UniformityCellSize <= 0.167\ngini = 0.458\nsamples = 489\nvalue = [315, 174]'),
#  Text(0.17647058823529413, 0.8636363636363636, 'BareNuclei <= 0.5\ngini = 0.114\nsamples = 300\nvalue = [288, 12]'),
#  Text(0.14705882352941177, 0.7727272727272727, 'BareNuclei <= 0.167\ngini = 0.034\nsamples = 292\nvalue = [287, 5]'),
#  Text(0.08823529411764706, 0.6818181818181818, 'ClumpThickness <= 0.389\ngini = 0.007\nsamples = 271\nvalue = [270, 1]'),
#  Text(0.058823529411764705, 0.5909090909090909, 'BareNuclei <= 0.056\ngini = 0.009\nsamples = 213\nvalue = [213, 0]'),
#  Text(0.029411764705882353, 0.5, 'gini = 0.0\nsamples = 197\nvalue = [197, 0]'),
#  Text(0.08823529411764706, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.11764705882352941, 0.5909090909090909, 'gini = 0.0\nsamples = 58\nvalue = [57, 1]'),
# ...
