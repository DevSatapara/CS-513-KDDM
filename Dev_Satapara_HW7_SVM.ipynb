# %%
# Course ID:- CS-513A
# Course Instructor:- Khashayar Dehnad
# Name:- Dev Satapara
# CWID:- 20021369
# Assignment Brief:- Performed SVM Methodology to develop a classification model for given dataset.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
df =  pd.read_csv('wisc_bc_ContinuousVar.csv',na_values='?')
df
# Out:
#                                                                                                                                                          Sample code  \
# 842302   M 17.99 10.38 122.80 1001.0 0.11840 0.27760 0.30010 0.14710 0.2419 0.07871 1.0950 0.9053 8.589 153.40 0.006399 0.04904 0.05373 0.01587 0.03003     0.006193
# 842517   M 20.57 17.77 132.90 1326.0 0.08474 0.07864 0.08690 0.07017 0.1812 0.05667 0.5435 0.7339 3.398 74.08  0.005225 0.01308 0.01860 0.01340 0.01389     0.003532
# 84300903 M 19.69 21.25 130.00 1203.0 0.10960 0.15990 0.19740 0.12790 0.2069 0.05999 0.7456 0.7869 4.585 94.03  0.006150 0.04006 0.03832 0.02058 0.02250     0.004571
# 84348301 M 11.42 20.38 77.58  386.1  0.14250 0.28390 0.24140 0.10520 0.2597 0.09744 0.4956 1.1560 3.445 27.23  0.009110 0.07458 0.05661 0.01867 0.05963     0.009208
# ...

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 0, 'B': 1}).fillna(df['diagnosis'])

# %%
df
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          0        17.99         10.38          122.80
# 1      842517          0        20.57         17.77          132.90
# 2    84300903          0        19.69         21.25          130.00
# 3    84348301          0        11.42         20.38           77.58
# 4    84358402          0        20.29         14.34          135.10
# ..        ...        ...          ...           ...             ...
# 564    926424          0        21.56         22.39          142.00
# 565    926682          0        20.13         28.25          131.20
# 566    926954          0        16.60         28.08          108.30
# 567    927241          0        20.60         29.33          140.10
# 568     92751          1         7.76         24.54           47.92
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11840           0.27760         0.30010
# ...

# %%
X = df.drop(["id" ,"diagnosis"],axis=1)
y = df["diagnosis"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
SVM = SVC(kernel='linear', C=1.0)
SVM.fit(X_train, y_train)

y_pred = SVM.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# [[ 64   3]
#  [  3 101]]

# %%
accuracy = accuracy_score(y_test, y_pred)*100
print(accuracy)
# Out:
# 96.49122807017544
